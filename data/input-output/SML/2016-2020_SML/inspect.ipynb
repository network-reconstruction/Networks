# %%
#import 2020_SML.csv inspect as pandas show many columns and rows
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
#load csv
df = pd.read_csv('/users/mf23yyt/Thesis/network_reconstruction/data/input-output/SML/2016-2020_SML/preprocessed/2016_SML/countries_intermediate_use/ARG_intermediate_use.csv')
#show row and columns 3464 - 3474
# df.set_index(df.columns[0], inplace=True)
# df.index.name = None
df
# df.head(10)

# df.iloc[3460:3474]
#show index of ARG_HFCE column

# df.columns.get_loc('ARG_HFCE')
# Out:
#             V1  ARG_A01_02   ARG_A03  ARG_B05_06  ARG_B07_08   ARG_B09  \
# 0   ARG_A01_02   6715.3233   25.6137      2.9099      2.8416    0.0000
# 1      ARG_A03      5.3468   87.4997      0.0428      0.0003    0.0026
# 2   ARG_B05_06      4.9437    0.1199    261.7120     10.0641   29.8039
# 3   ARG_B07_08      0.8736    0.1744     68.4119    266.8836    0.0143
# 4      ARG_B09      0.0000    0.0000   3822.4815     63.9287  131.6347
# 5   ARG_C10T12   2149.9968   24.6897     16.9296     11.7089    4.5195
# 6   ARG_C13T15    170.1944   11.9664     63.9606      1.4814   19.8541
# 7      ARG_C16     36.8641    0.4826      0.7714      0.3154    0.1675
# 8   ARG_C17_18     11.7533   14.2119      2.5654     53.5335   13.2777
# 9      ARG_C19    880.3095   70.2392     15.9403    112.9045   37.8248
# 10     ARG_C20    819.8026    5.9025      8.0642     62.3345    8.0901
# 11     ARG_C21    245.8449    2.1054     10.0449      5.8567    2.4498
# ...
